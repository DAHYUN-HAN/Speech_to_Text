# %%
with open('conti_script_print.txt', 'r') as f:
    data = f.read()
script_data = data.splitlines()

# %%
script_data
# Out:
# [' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '3월인데 여전히 춥다. ',
#  '분명히 C동 1층이었는데.',
#  '여기쯤인데. 왜 팻말이 없지?',
#  '잠시만요!!',
#  '저기 괜찮아요?',
#  '아!!! 아파!! 아파~~~!!',
#  '“위 동아리는 2019년 11월 30일 자로 폐부를 통지함.”',
#  '“해당 일까지 동아리 방을 비우고 동아리 연합회에 폐부신고서를 제출하기 바람”',
#  '형, 누나, 어떡해! 설마가 진짜가 됐어!',
#  '뭐야! 안 놀래? ',
#  '작년에 폐부 권고 통지받았고, 그거대로 올해 폐부통지서가 온 거잖아.',
#  '우리 연극부의 겸둥이 유가 놀람 모드로 급 등장.',
#  '우리 유 진짜 이쁘죠?',
#  '제가 빠른 시일 내 유랑 같이 연극 분장 라방 준비할게요.',
#  '밤 열한시에 다시 만나요. 안녕 ~',
#  '누나아-',
#  '폐부 권고 아니었음 도래 오빠가 공연 올릴 맘도 안 먹었을걸?',
#  '불행 중 다행이라 생각해.',
#  '버퍼링 긴 도래한테는 이 정도는 되야 자극이 되나봐. ',
#  '연극부 들어와서 1년 반 만에 제대로 된 연극할 줄 알았는데 폐부라니! 말도 안돼!',
#  '폐부 되면 난 어디가?',
#  '군대. ',
#  '뭐야, 형! 팔 왜 그래? ',
#  '말하자면 사연이 길다.   ',
#  '또 어디서 뒹굴었어?',
#  '짜잔! 여기 집중!',
#  '내 팔을 이 지경으로 만든 가해자이자 연극부 신입 부원, 철학과 3학년 이찬란을 소개합니다.',
#  '헐, 신입부원?',
#  '안녕하세요. 기획을 맡은 최시온입니다.',
#  '난 분장, 의상 담당 진.',
#  '전 활기 담당 유라고 해~유! ',
#  '난 연극부 회장 윤도래.',
#  '연극부에 오신 걸 다시 한번 환영합니다! ',
#  '잠깐만요, 무슨 오해가 있는 것 같은데, 전 여기서 빌려 간 옷을 돌려주려 온 것 뿐이에요.',
#  '어제, 여기 제 발로 찾아왔잖아.',
#  '옷? 내가 모르는 의상 반출이 있었어?',
#  '어제 페인트통 발로 팍, 옷에 찍! ',
#  '나중이라도 나한테 말을 해줬어야지!',
#  '얘가 내 팔 이렇게 만들고...',
#  '그건 고의가 아니라 실수였어요. 변태인줄....',
#  '애니웨이!! 페인트 뒤집어쓴 채 다닐 순 없어서 연극부 의상 렌트.',
#  '그건 그쪽이 막무가내로.',
#  '인간적으로 그냥 돌려보낼 수는 없잖아.',
#  '저기요! 어쨌든 전 제 할 일 다 했어요. 안녕히 계세요.',
#  '잠깐, 너, 내 팔을 이렇게 만들어 놓고 이렇게 가겠다고? 신입 부원 등록 해야지.',
#  '정말 일관되게 무례하시네요.',
#  '저기! 실례가 안 된다면 제가 잠시 개입을. 어떤 상황인지 이제 알겠네요. 찬란씨, 당황스럽게 한 점 대신 사과드릴게요. 반드시 연극부에 들어올 필요는 없지만, 그래도 한 번 제대로 된 설명 들어보고 생각해보면 어떨까요? 여기는 지난 몇 년 동안 공연을 올리지 않은 유령 연극부예요. 작년에 폐부 권고를 받았는데, 올해 말, 폐부 되기 전에 마지막으로 저희가 공연을 올리려고 합니다. 그래서 1년 동안 함께해줄 신입 부원을 찾다가, 글쎄, 이 녀석이 그쪽이 무척 마음에 들었나 봐요.',
#  '4차 산업혁명 시대에 무슨 연극인가 싶죠? 좀 올드하긴 한데 완전 아날로그 연극작업이 은근 재밌어요. ',
#  '여기 저 빼고 다 4학년이에요, 복학 둘, 재수하나. 전 파릇파릇한 현역 2학년. ',
#  '부담스럽겠지만 한번 진지하게 고민을...',
#  '저는...',
#  '저는?',
#  '.......그렇게 한가하지 못합니다.',
#  '이 사람들 뭐죠? 정말 왜들 이러는 거야... 삭제, 삭제 삭제.... 당신이 제일 문제야... 나가! 뭐야... 나가!!',
#  '너 혼자 뭐해...? 넌 무슨 애가 그렇게 걸음이 빠르냐?',
#  '아무리 한가하지 못해도, 잠깐 얘기할 시간은 있지? 자, 내가 좋아하는 초코우유',
#  '괜찮아요.',
#  '사오느라 힘들었어.',
#  '갚을게요. 1200원.',
#  '다음에 더 맛잇는걸로 갚아.',
#  '그런데 언제 봤다고 자꾸 반말하세요?',
#  '봤다면 봤지.',
#  '?',
#  '너. 1년 전에 무슨 토론 수업 들었지?',
#  '네?!',
#  '나 그 수업 청강했는데, 말할 때마다 눈에 띄었어. 그 수업 애들이 널 엘사라 부르던데? 주위 시선 아랑곳하지 않고 꼭 해야 할 말은 하는 엘사.',
#  '그때 봤다고 지금 반말하는 거예요?',
#  '너도 말 놔.',
#  '전 그쪽이 아주 낯선데요.',
#  '내가 낯선 매력이 좀 넘치지. 천천히 놔. 기다릴게.',
#  '아, 정말....',
#  '잠시만, 역시 넌 1년 전이나 지금이나 여전하구나. 다행이다.',
#  '저 아세요? 그리고 뭐가 다행이에요?',
#  '다행이지. 내가 널 내 이야기의 주인공으로 픽했으니까!',
#  '네에?',
#  '대체 뭐 때문에 연극부를 못 한다는 거야?',
#  '저 그럴 시간 없다고요.',
#  '그러니까, 왜 그럴 시간이 없냐고? 벌써 취업이라도 된 거야?',
#  '평일 오전 빵집 알바, 오후 수업, 저녁 토익 공부. 주말은 카페 알바...',
#  '도대체 알바를 몇 개를 하는 거야?! ',
#  '월세, 교통비, 생활비, 그리고 집에 돈도 좀 보태야 하고. 그러려면 한 달에 100은 벌어야 해요.',
#  '돈 문제만 해결하면, 이번 공연 할 수 있는 거지? 약속해, 돈 해결하면 연극부 마지막 공연 같이한다고.',
#  '관심 없어요.',
#  '이제부터 관심이 생길 거야! 내가 그렇게 만들 거니까. 그리고 궁금할까 말해주는 건데 팔은 괜찮대. 그냥 근육이 놀랐다고 하더라고. 그럼 수고!',
#  '도대체 뭐야... 저 사람...',
#  '어, 찬란씨! 여기서 점심 먹어요?',
#  '아?!?!?! 근데 누구신지?!',
#  '저,..연..극부 최시온. 난 중도에서 젤 가까워서. ',
#  '전 젤 싸서.',
#  '오늘 메뉴 괜찮죠? 우리 연극부가 좀 엉뚱하긴 해도 다 좋은 사람들이에요. 그냥 그렇다고 꼭 말해주고 싶었어요. 아! 맞다. 여기 귤 세 개. 세 개는 먹어야 한 대요. 하루 성인여자 기준으로 비타민 권장섭취량이 75mg이래요. 그럼, 이만 가볼게요.',
#  '네...',
#  '다름이 아니라, 혹시 알바시간을 좀 더 늘릴 수 있을까요?',
#  '아,네...',
#  '그럼, 확인 되시면 전화주세요. 감사합니다.',
#  '언제 왔어요?',
#  '방금 왔어.',
#  '제 사적인 시간은 지켜주기로 하셨잖아요.',
#  '오늘 오전에 연습하기로 했잖아.',
#  '저는 모르는 일 이에요.',
#  '무슨 소리야?',
#  '누나 굿모닝! 잘 잤어?',
#  '왜 너만 연습시간을 모르고 있어?',
#  '단체방 확인 좀 잘 하자.',
#  '아, 어제 단체방에 너무 늦게 올라와서 누나가 확인을 못 했나봐.',
#  '앞으로 잘 하면 되지 뭐.',
#  '좋은 아침!',
#  '시온아. 새 대본 나눠줄래?',
#  '자 따끈따끈한 수정 대본이 나왔습니다.',
#  '메이킹영상 촬영할게요.',
#  '네.',
#  '현대, 같은 구조의 301호, 302호의 방이 마주 보고 있다.',
#  'A, B는 말없이 일상을 시작한다.',
#  'B는 책상에 앉아 공무원 시험을 준비한다.',
#  '“드디어 내일이 시험이다. 벌써 4년 째... 이번엔 꼭!” ',
#  '다음날, 같은 공간. ',
#  '“하... 이번에 떨어지면 엄마 얼굴 어떻게 보지?”',
#  '그 날 오후, A는 알바 중 취업 탈락 통보 문자를 받고, 설상가상 손님에게 컴플레인이 들어와, 사장에게 갖은 욕을 듣는다.',
#  '“이걸로 스물... 일곱 번째 인가? 내 나이만큼 까였네.”',
#  '그 날 저녁, A와 B는 방 앞에서 마주친다.',
#  '“휴...”',
#  '3장. 같은 날 자정, 고시원 옥상.',
#  '여기서부터는 수정 된 부분이니, 대본 들고 해보자. ',
#  '“저, 저기요! 지금 뛰어내리려는 거예요?”',
#  '“말리지 마요! 그래도 소용없어요.”',
#  '“아니... 말리려는 게 아니고 제가 먼저 뛰어내리면 안 될까요?”',
#  '“뭐라고요?”',
#  '“저도 정말 힘들게 오늘 죽기로 마음먹었거든요. 지금 아니면 못할 거 같은데. 제가 먼저 뛴 다음에 뛰시면 안 될까요?”',
#  '“하, 그럼 저더러 죽기 전에 그쪽 죽는 거 먼저 보라고요?”',
#  '“죄송해요. 그쪽이 먼저 죽으면 소란스러워지잖아요. 전 조용히 죽고 싶거든요.”',
#  '“너무 이기적인 거 아니에요?”',
#  '“전 평생을 남 눈치만 보면서 살았어요. 죽을 때만이라도 좀 이기적이면 안 되나요?”',
#  '“저는요, 다른 인간들한테 밀리기만 하면서 살아왔어요. 죽는 거까지 밀릴 수는 없잖아요.”',
#  '“그럼 이렇게 하는 거 어때요? 누가 먼저 죽을 만한지 서로 이야기 들어보고 정하기로.”',
#  '“그래요.”',
#  '어때?',
#  '주제도 명확하고 난 좋아. 이 방향으로 공연 기획안 짜고, 예산도 짜볼게. 연습은 더 해야겠지? ',
#  '난 시장 조사하러 갈게.',
#  '나도 갈게.',
#  '넌 왜 같이 가?',
#  '기획안을 쓰려면 예산을 정확하게 잡아야지. 안 그래?',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ']

# %%
for i in range (len(script_data)):
    sentence = script_data[i].replace(" ", "")
    sentence = sentence.replace(".", "")
    sentence = sentence.replace(",", "")
    sentence = sentence.replace("!", "")
    sentence = sentence.replace("?", "")
    sentence = sentence.replace("~", "")
    sentence = sentence.replace('“', "")
    sentence = sentence.replace('”', "")
    sentence = sentence.replace('"', "")
    sentence = sentence.replace('-', "")
    script_data[i] = sentence

# %%
with open('conti_script_compare.txt', 'w') as f:
    for line in script_data:
        f.writelines(line+'\n')
